# %%
import pandas as pd
df = pd.read_csv('data/-DI-qnd-mol.csv')
df
# Out:
#        Number  m000     m100     m010  m001        xmean       ymean  \
# 0           0  10.0     35.0   3960.0  10.0     3.500000  396.000000
# 1           1   4.0     10.0   1982.0   0.0     2.500000  495.500000
# 2           2   5.0     31.0   2042.0   0.0     6.199999  408.399999
# 3           3  22.0    194.0   7807.0  30.0     8.818181  354.863636
# 4           4   4.0     26.0   1806.0   0.0     6.500000  451.500000
# ...       ...   ...      ...      ...   ...          ...         ...
# 17268   17268  10.0  17810.0   5375.0  10.0  1781.000000  537.500000
# 17269   17269   8.0  14257.0   3473.0   0.0  1782.125000  434.125000
# 17270   17270   8.0  14263.0   3431.0  16.0  1782.875000  428.875000
# 17271   17271  25.0  44629.0  12385.0  42.0  1785.159999  495.399999
# 17272   17272   4.0   7142.0   1938.0  12.0  1785.500000  484.500000
#
#           zmean     mu002      mu020  ...  PlaneMax  DImol_mean   DImol_var  \
# ...

# %%
import matplotlib.pyplot as plt

column_name = df.columns[38]
print(column_name)
plt.hist(df[column_name], bins=55, edgecolor='black')

plt.xlabel('Значение')
plt.ylabel('Частота')

plt.show()
# Out:
# DImol_mean

# %%
df.columns
# Out:
# Index(['Number', 'm000', 'm100', 'm010', 'm001', 'xmean', 'ymean', 'zmean',
#        'mu002', 'mu020', 'mu200', 'mu110', 'mu101', 'mu011', 'eta002',
#        'eta020', 'eta200', 'eta110', 'eta101', 'eta011', 'I_1', 'I_2', 'I_3',
#        'J_1', 'J_2', 'J_3', 'EllipsoidalAxisA', 'EllipsoidalAxisB',
#        'EllipsoidalAxisC', 'RowMean', 'ColumnMean', 'PlaneMean', 'RowMin',
#        'ColumnMin', 'PlaneMin', 'RowMax', 'ColumnMax', 'PlaneMax',
#        'DImol_mean', 'DImol_var', 'DImol_stdev', 'DImol_max', 'DImol_min',
#        'DImol_median', 'DImol_muc', 'DImol_notempty', 'celnumber'],
#       dtype='object')
